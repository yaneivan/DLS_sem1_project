# %% [markdown]
# https://github.com/TadasBaltrusaitis/OpenFace
#
# Предлагают инструменты для работы с лицами, детекция, ключевые точки, поворот и наклон определять, направление взгляда (лол, оказывается такой смешной фильтр можно было еще 4 года назад сделать)
#
# ![maxresdefault-3339097802.jpg](attachment:maxresdefault-3339097802.jpg)
#
# Можно фичи лица извлекать, но напрямую распознования лиц у них нет.

# %% [markdown]
# https://github.com/akshitagupta15june/Face-X
#
# Сборник различных алгоритмов с лицами. Скорее как обучающие матриалы интересные.

# %% [markdown]
# https://github.com/exadel-inc/CompreFace
#
# Сервис, который можно развернуть не залезая абсолютно в ML. Поэтому развернуть можно только как докер. Докер я недавно снес, поэтому не рассматриваю.
