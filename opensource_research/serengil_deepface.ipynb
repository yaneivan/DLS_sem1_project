# %% [markdown]
# https://github.com/serengil/deepface

# %% [markdown]
# Легкая библиотека, для работы с лицами. Определение возраста, пола, эмоций, расы. Используют несколько моделей для этого.
#
# Говорят что распознают лица лучше чем это делает человек.
#
# Установка через
# ```
# pip install deepface
# ```
#
# Дальше импорт в питон как библиотеку.

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From c:\Users\admin\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
result = DeepFace.verify(img1_path = "../test_images/kim1.jpg", img2_path = "../test_images/kim2.jpg")
result
# Out:
# {'verified': True,
#  'distance': 0.3351285767058805,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 1334,
#    'y': 234,
#    'w': 821,
#    'h': 821,
#    'left_eye': (1897, 578),
#    'right_eye': (1639, 552)},
#   'img2': {'x': 366,
#    'y': 239,
#    'w': 469,
#    'h': 469,
#    'left_eye': (672, 426),
#    'right_eye': (525, 427)}},
#  'time': 3.71}

# %%
result = DeepFace.verify(img1_path = "../test_images/kim1.jpg", img2_path = "../test_images/putin1.jpg")
result
# Out:
# {'verified': False,
#  'distance': 0.9412334986353071,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 1334,
#    'y': 234,
#    'w': 821,
#    'h': 821,
#    'left_eye': (1897, 578),
#    'right_eye': (1639, 552)},
#   'img2': {'x': 397,
#    'y': 24,
#    'w': 868,
#    'h': 868,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 3.57}

# %% [markdown]
# Есть функция для поиска человека в архиве. Для этого весь архив перевеодится в вектора, это долгая операция, но она кешируется. Например в этом случае она создаст pkl (pickle) файл в test_images

# %%
dfs = DeepFace.find(img_path = "../test_images/kim1.jpg", db_path = "../test_images/")
dfs
# Out:
# 25-07-06 14:57:28 - Found 25 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations: 100%|██████████| 25/25 [00:19<00:00,  1.27it/s]
# 25-07-06 14:57:47 - There are now 27 representations in ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 25-07-06 14:57:47 - Searching ../test_images/kim1.jpg in 27 length datastore
# 25-07-06 14:57:50 - find function duration 22.83314347267151 seconds
# [                  identity                                      hash  \
#  0  ../test_images/kim1.jpg  54664778df9a83681857cd3f90b1728497111045
#  1  ../test_images/kim5.jpg  4c43efd0711c0cb7c9c2a1a97451dbda4e51ce50
#  2  ../test_images/kim2.jpg  5f135f33468563cf34cc0109b1373f722443eb55
#
#     target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
#  0      1334       234       821       821      1334       234       821
#  1        75        54       154       154      1334       234       821
# ...

# %% [markdown]
# По умолчанию модель достаточно тяжелая. Я считаю что у меня норм процессор, и даже тут 1.27 it/s. Что маловато будет, если у нас много лиц будет. При первом запуске модель скачивалась, 580мб, что тоже относительно много. Но есть возможность использовать другие модели.

# %% [markdown]
# Есть функционал подсчета только эмбеддингов.
#
# В библиотеке есть логика для работы с видео.
#
# Есть интересная идея - сделать anti spoofing. Можно включить при извлечении лиц.
# ![face-anti-spoofing.jpg](attachment:face-anti-spoofing.jpg)
#
# Библиотека кажется более гибкой чем face_recognition. Она лучше документирована, проще устанавливается, множество примеров использования. Например даже есть пример как можно использовать распознование лиц чтобы определить на кого сильнее из родителей ребенок похож.
# ![parental-look-alike-scaled.jpg](attachment:parental-look-alike-scaled.jpg)
